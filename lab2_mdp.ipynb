# %% [markdown]
# <a href="https://colab.research.google.com/github/vap326/cse337/blob/main/lab2_mdp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 2: Markov Decision Problems
#
# # Exercise 1: Grid World
# Compute the value funnction for the example 4.1 in the book.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


V = np.zeros(16)
gamma = 0.95  # Discount factor
V_old = np.zeros(16)

for k in range(10):
  for s in range(16):
    s_new = s
    policy_probability = 0.25

    if s==0 or s==15:
      continue
    else:
        v = 0

        valid_actions = []

        for a in range(4):
            if a == 0:  # right
              if s % 4 == 3:
                    s_new = s
              else:
                s_new = s + 1
            elif a == 1:  # left
                if s % 4 == 0:
                    s_new = s
                else:
                  s_new = s - 1
            elif a == 2:  # down
              if s >= 12:
                    s_new = s
              else:
                s_new = s + 4
            else:  # up
              if s <= 3:
                    s_new = s
              else:
                s_new = s - 4

            valid_actions.append(s_new)

        for s_new in valid_actions:
            reward = -1
            v += policy_probability * (reward + gamma * V_old[s_new])

        V[s] = v


    #### Write your code here #########

  V_old = V.copy()




  ###### PLOT
  # Reshape the 1D value function array into an 8x8 grid
  V_grid = V.reshape((4, 4))

  # Plot the value function as a heatmap
  plt.figure(figsize=(4, 4))
  sns.heatmap(V_grid, annot=True, cmap="viridis", fmt=".1f", linewidths=.5)
  plt.title("Value Function k=%d"%(k+1))
  plt.xlabel("Column")
  plt.ylabel("Row")
  plt.show()

# %% [markdown]
# # Exercise 2: Grid World
# Compute the optimal policy

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


V = np.zeros(16)
gamma = 0.95  # Discount factor
V_old = np.zeros(16)
action_names = ['Right', 'Left', 'Down', 'Up']

for k in range(10):
  for s in range(16):
    s_new = s
    policy_probability = 0.25

    if s==0 or s==15:
      continue
    else:
        v = 0

        q_values = []

        for a in range(4):
            if a == 0:  # right
              if s % 4 == 3:
                    s_new = s
              else:
                s_new = s + 1
            elif a == 1:  # left
                if s % 4 == 0:
                    s_new = s
                else:
                  s_new = s - 1
            elif a == 2:  # down
              if s >= 12:
                    s_new = s
              else:
                s_new = s + 4
            else:  # up
              if s <= 3:
                    s_new = s
              else:
                s_new = s - 4

            reward = -1
            q_value = reward + gamma * V_old[s_new]
            q_values.append(q_value)

        V[s] = max(q_values)


    #### Write your code here #########

  V_old = V.copy()

  optimal_policy = np.zeros(16, dtype=int)
  policy_grid = np.full((4, 4), '', dtype=object)

  for s in range(16):
    s_new = s

    if s==0 or s==15:
      continue
    else:
        v = 0

        q_values = []

        for a in range(4):
            if a == 0:  # right
              if s % 4 == 3:
                    s_new = s
              else:
                s_new = s + 1
            elif a == 1:  # left
                if s % 4 == 0:
                    s_new = s
                else:
                  s_new = s - 1
            elif a == 2:  # down
              if s >= 12:
                    s_new = s
              else:
                s_new = s + 4
            else:  # up
              if s <= 3:
                    s_new = s
              else:
                s_new = s - 4

            reward = -1
            q_value = reward + gamma * V_old[s_new]
            q_values.append(q_value)

        best_action = np.argmax(q_values)
        optimal_policy[s] = best_action

        arrows = ['→', '←', '↓', '↑']
        policy_grid[s//4, s%4] = arrows[best_action]

  print("\nOptimal Policy (arrows show best action):")
  for i in range(4):
      print(' '.join(f'{policy_grid[i,j]:^3}' for j in range(4)))


  ###### PLOT
  # Reshape the 1D value function array into an 8x8 grid
  V_grid = V.reshape((4, 4))

  # Plot the value function as a heatmap
  plt.figure(figsize=(4, 4))
  sns.heatmap(V_grid, annot=True, cmap="viridis", fmt=".1f", linewidths=.5)
  plt.title("Value Function k=%d"%(k+1))
  plt.xlabel("Column")
  plt.ylabel("Row")
  plt.show()
# Out:
# Optimal Policy (arrows show best action):
#      ←   →   →
#  ↑   →   →   →
#  →   →   →   ↓
#  →   →   →
# Optimal Policy (arrows show best action):
#      ←   ←   →
#  ↑   ←   →   ↓
#  ↑   →   →   ↓
#  →   →   →
# Optimal Policy (arrows show best action):
#      ←   ←   ←
#  ↑   ←   →   ↓
#  ↑   →   →   ↓
#  →   →   →
# Optimal Policy (arrows show best action):
#      ←   ←   ←
#  ↑   ←   →   ↓
#  ↑   →   →   ↓
#  →   →   →
# Optimal Policy (arrows show best action):
#      ←   ←   ←
#  ↑   ←   →   ↓
#  ↑   →   →   ↓
#  →   →   →
# Optimal Policy (arrows show best action):
#      ←   ←   ←
#  ↑   ←   →   ↓
#  ↑   →   →   ↓
#  →   →   →
# Optimal Policy (arrows show best action):
#      ←   ←   ←
#  ↑   ←   →   ↓
#  ↑   →   →   ↓
#  →   →   →
# Optimal Policy (arrows show best action):
#      ←   ←   ←
#  ↑   ←   →   ↓
#  ↑   →   →   ↓
#  →   →   →
# Optimal Policy (arrows show best action):
#      ←   ←   ←
#  ↑   ←   →   ↓
#  ↑   →   →   ↓
#  →   →   →
# Optimal Policy (arrows show best action):
#      ←   ←   ←
#  ↑   ←   →   ↓
#  ↑   →   →   ↓
#  →   →   →

# %% [markdown]
# # Exercise 3: Grid World
# In the following gym environment, compute the value function using Monte Carlo.
#
# Run the following code in your local machine. You can run in on colab, but you will not see the animation.

# %%
## Install https://github.com/damat-le/gym-simplegrid
# !pip install gym_simplegrid
# Out:
# Collecting gym_simplegrid
#   Downloading gym_simplegrid-1.0.6-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (from gym_simplegrid) (1.2.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from gym_simplegrid) (3.10.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium->gym_simplegrid) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium->gym_simplegrid) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium->gym_simplegrid) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium->gym_simplegrid) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gym_simplegrid) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gym_simplegrid) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gym_simplegrid) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gym_simplegrid) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gym_simplegrid) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gym_simplegrid) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gym_simplegrid) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gym_simplegrid) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->gym_simplegrid) (1.17.0)
# Downloading gym_simplegrid-1.0.6-py3-none-any.whl (12 kB)
# Installing collected packages: gym_simplegrid
# Successfully installed gym_simplegrid-1.0.6

# %%
import gymnasium as gym
import gym_simplegrid

START_LOC = 15
GOAL_LOC = 3
# Define the initial location and the goal location in the grid.
# Each grid cell has an a number from 0 to 63.
options ={
    'start_loc': START_LOC,
    'goal_loc': GOAL_LOC
}

env = gym.make('SimpleGrid-8x8-v0', render_mode='human')
obs, info = env.reset(seed=1, options=options)
done = env.unwrapped.done

for t in range(10):
    if done:
        break
    action = env.action_space.sample()   # Random action
    obs, reward, done, _, info = env.step(action)

    grid_size = 8
    row = obs // grid_size
    col = obs % grid_size
    print("Location (", row, ",", col, ") t=",t, " reward=", reward, sep="")

# env.close()
# Out:
# Location (1,7) t=0 reward=-1.0
# Location (2,7) t=1 reward=0.0
# Location (2,6) t=2 reward=0.0
# Location (2,7) t=3 reward=0.0
# Location (3,7) t=4 reward=0.0
# Location (3,7) t=5 reward=-1.0
# Location (4,7) t=6 reward=0.0
# Location (5,7) t=7 reward=0.0
# Location (4,7) t=8 reward=0.0
# Location (4,6) t=9 reward=0.0
